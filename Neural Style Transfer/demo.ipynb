# %%
import os
from utilis import *
from visu import *

# %% [markdown]
# # 1. Load and display content and style images

# %%
style_imgs, content_imgs = imgs_for_demo()
display_style_content(content_imgs, ['Field', 'City'])
display_style_content(style_imgs, ['Expressionism','Impressionism','Realism'])

# %% [markdown]
# # 2. Start transfer

# %% [markdown]
# It should take roughly 2 mins to transfer two content images on three different types of style images on GPU.

# %%
output = style_transfer_demo(content_imgs, style_imgs)
# Out:
# 1/6. Content: Field, Style: Expressionism transfer start!
#
# Building the style transfer model...
# Optimizing...
#
# run 50/200, Style Loss: 821.997620, Content Loss: 38.402283
# run 100/200, Style Loss: 402.396881, Content Loss: 42.290836
# run 150/200, Style Loss: 220.840454, Content Loss: 44.327377
# run 200/200, Style Loss: 127.251595, Content Loss: 45.324127
# Transfering complete in 0m 21s
#
# Content: Field, Style: Expressionism transfer complete!
# ----------------------------------------------------------
#
# 2/6. Content: Field, Style: Impressionism transfer start!
#
# Building the style transfer model...
# Optimizing...
#
# run 50/200, Style Loss: 121.597534, Content Loss: 35.018642
# run 100/200, Style Loss: 46.964310, Content Loss: 33.717304
# run 150/200, Style Loss: 30.881870, Content Loss: 32.269150
# run 200/200, Style Loss: 22.747913, Content Loss: 30.743401
# Transfering complete in 0m 21s
#
# Content: Field, Style: Impressionism transfer complete!
# ...

# %% [markdown]
# # 3. Display result

# %%
display_demo_result(output, content_imgs)
