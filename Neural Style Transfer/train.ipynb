# %%
import os
from utilis import *
from visu import *

# %%
style_img = image_loader(os.path.join('/datasets/ee285f-public/wikiart/wikiart',
                                      'Abstract_Expressionism/elaine-de-kooning_untitled-1965.jpg'))
content_img = image_loader(os.path.join('/datasets/ee285f-public/flickr_landscape',
                                        'field/8883092521_071c314fc6.jpg'))
input_img = content_img.clone().detach().requires_grad_(True)

# %%
display(style_img[0], content_img[0])

# %%
vgg = models.vgg19(pretrained=True).features.to(device).eval()

# %%
output = run_style_transfer(vgg, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input_img)
# Out:
# Building the style transfer model...
# Optimizing...
# run [50], Style Loss: 78.171936, Content Loss: 35.737537
# run [100], Style Loss: 41.078983, Content Loss: 36.611343
# run [150], Style Loss: 24.798248, Content Loss: 36.174088
# run [200], Style Loss: 15.582583, Content Loss: 35.361938
# run [250], Style Loss: 10.852777, Content Loss: 34.281483
# run [300], Style Loss: 8.521703, Content Loss: 33.187702
# run [350], Style Loss: 7.113555, Content Loss: 32.410213
# run [400], Style Loss: 6.089737, Content Loss: 31.746275
# run [450], Style Loss: 5.427885, Content Loss: 31.160669
# run [500], Style Loss: 4.935705, Content Loss: 30.741547

# %%
plt.title('Transfered')
plt.axis('off')
plt.imshow(convert(output[0]))
